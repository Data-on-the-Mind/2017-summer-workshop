# %% [markdown]
# # Data migration tools
#
# Sometimes the data you have is not in the format you want it in.
#
# For example, say you were handed a set of CSV files, but now that you've learned to use `tidyverse`, the SciPy stack, and other tools, you want the data in a more pliable format that you're familiar with.
#
# What you need is a data-migration tool that will convert your data into whatever format your heart desires.
#
# `odo` is one such data-migration tool, notable for its unique approach to data migration. The project maintains a network of one-to-one migration subtools, with the ability to migrate between any two formats in the network by traversing the shortest path between them.
#
# Let's start with a simple migration from CSV to a pandas DataFrame.
#
# First, import `odo` and `pandas`:

# %%
from odo import odo
import pandas as pd

# %% [markdown]
# Next, we migrate the data:

# %%
data = odo("data/node.csv", pd.DataFrame)
data
# Out:
#    id              creation_time property1 property2 property3 property4  \
# 0   1 2017-04-02 02:15:12.803403       NaN       NaN       NaN       NaN
# 1   2 2017-04-02 02:15:16.840293       NaN       NaN       NaN       NaN
# 2   3 2017-04-02 02:15:33.129487       NaN       NaN       NaN       NaN
# 3   4 2017-04-02 02:15:48.309461       NaN       NaN       NaN       NaN
# 4   5 2017-04-02 02:16:03.502076       NaN       NaN       NaN       NaN
#
#   property5 failed time_of_death                      type  network_id  \
# 0       NaN      f           NaN  war_of_the_ghosts_source           1
# 1       NaN      f           NaN                      node           1
# 2       NaN      f           NaN                      node           1
# 3       NaN      f           NaN                      node           1
# 4       NaN      f           NaN                      node           1
#
#    participant_id
# 0             NaN
# 1             1.0
# 2             2.0
# 3             3.0
# 4             4.0

# %% [markdown]
# Tada!
#
# `tablib` is another such data-migration tool, with support for different formats.
#
# First, install tablib:

# %%
# !pip2 install tablib===0.11.5
# Out:
# Requirement already satisfied: tablib===0.11.5 in /usr/local/lib/python2.7/site-packages
# Requirement already satisfied: xlwt in /usr/local/lib/python2.7/site-packages (from tablib===0.11.5)
# Requirement already satisfied: openpyxl in /usr/local/lib/python2.7/site-packages (from tablib===0.11.5)
# Requirement already satisfied: xlrd in /usr/local/lib/python2.7/site-packages (from tablib===0.11.5)
# Requirement already satisfied: odfpy in /usr/local/lib/python2.7/site-packages (from tablib===0.11.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python2.7/site-packages (from tablib===0.11.5)
# Requirement already satisfied: unicodecsv in /usr/local/lib/python2.7/site-packages (from tablib===0.11.5)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python2.7/site-packages (from openpyxl->tablib===0.11.5)
# Requirement already satisfied: jdcal in /usr/local/lib/python2.7/site-packages (from openpyxl->tablib===0.11.5)

# %% [markdown]
# Next, import `tablib`:

# %%
import tablib

# %% [markdown]
# Finally, migrate the data:

# %%
networks = tablib.Dataset().load(open('data/network.csv').read())

# %% [markdown]
# Now let's see what formats your data is available in. First, as a sanity check, CSV:

# %%
networks.csv
# Out:
# 'id,creation_time,property1,property2,property3,property4,property5,failed,time_of_death,type,max_size,full,role\r\n1,2017-04-02 02:15:12.797802,,,,,,f,,chain,5,t,experiment\r\n'

# %% [markdown]
# As JSON:

# %%
networks.json
# Out:
# '[{"id": "1", "creation_time": "2017-04-02 02:15:12.797802", "property1": "", "property2": "", "property3": "", "property4": "", "property5": "", "failed": "f", "time_of_death": "", "type": "chain", "max_size": "5", "full": "t", "role": "experiment"}]'

# %% [markdown]
# As YAML:

# %%
networks.yaml
# Out:
# "- {creation_time: '2017-04-02 02:15:12.797802', failed: f, full: t, id: '1', max_size: '5',\n  property1: '', property2: '', property3: '', property4: '', property5: '', role: experiment,\n  time_of_death: '', type: chain}\n"

# %% [markdown]
# As an Excel file:

# %%
networks.xls
# Out:
# '\xd0\xcf\x11\xe0\xa1\xb1\x1a\xe1\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00
# %% [markdown]
# Hm. What happened there?

# %%
with open('networks.xls', 'a') as f:
    f.write(networks.xls)

# %% [markdown]
# As an HTML table:

# %%
networks.html
# Out:
# u'<table>\n<thead>\n<tr><th>id</th>\n<th>creation_time</th>\n<th>property1</th>\n<th>property2</th>\n<th>property3</th>\n<th>property4</th>\n<th>property5</th>\n<th>failed</th>\n<th>time_of_death</th>\n<th>type</th>\n<th>max_size</th>\n<th>full</th>\n<th>role</th></tr>\n</thead>\n<tr><td>1</td>\n<td>2017-04-02 02:15:12.797802</td>\n<td></td>\n<td></td>\n<td></td>\n<td></td>\n<td></td>\n<td>f</td>\n<td></td>\n<td>chain</td>\n<td>5</td>\n<td>t</td>\n<td>experiment</td></tr>\n</table>'

# %% [markdown]
# As a LaTeX table:

# %%
networks.latex
# Out:
# u'% Note: add \\usepackage{booktabs} to your preamble\n%\n\\begin{table}[!htbp]\n  \\centering\n  %\n  \\begin{tabular}{lrrrrrrrrrrrr}\n    \\toprule\n      id & creation\\_time & property1 & property2 & property3 & property4 & property5 & failed & time\\_of\\_death & type & max\\_size & full & role \\\\\n    \\cmidrule(r){1-1} \\cmidrule(lr){2-2} \\cmidrule(lr){3-3} \\cmidrule(lr){4-4} \\cmidrule(lr){5-5} \\cmidrule(lr){6-6} \\cmidrule(lr){7-7} \\cmidrule(lr){8-8} \\cmidrule(lr){9-9} \\cmidrule(lr){10-10} \\cmidrule(lr){11-11} \\cmidrule(lr){12-12} \\cmidrule(l){13-13}\n      1 & 2017-04-02 02:15:12.797802 &  &  &  &  &  & f &  & chain & 5 & t & experiment \\\\\n    \\bottomrule\n  \\end{tabular}\n\\end{table}\n'

# %% [markdown]
# As an OpenDocument Spreadsheet:

# %%
networks.ods
# Out:
# 'PK\x03\x04\x14\x00\x00\x00\x00\x00\xbd\xaa\xdbJ\x85l9\x8a.\x00\x00\x00.\x00\x00\x00\x08\x00\x00\x00mimetypeapplication/vnd.oasis.opendocument.spreadsheetPK\x03\x04\x14\x00\x00\x00\x08\x00\xbd\xaa\xdbJ\\\xf6\xfc\xa6\xc9\x00\x00\x00o\x02\x00\x00\n\x00\x00\x00styles.xml\x8d\x92K\x0e\x820\x10\x86\xf7\x9e\x82\xb0a\x05\x88+\xd3\xf0\xd8y\x02=@-S\xd3\x84\xce\x10Z\x0c\xde\xde\n\xd4 \x1b\xbb\xeb\xe3\xfff\x9a\xf9Z6\x93\xee\xa2\'\x0cF\x11VI\x91\x1d\x93\x08PP\xab\xf0Q%\xb7\xeb%=\'M}(IJ%\x80\xb5$F\rhSc_\x1d\x98\xc8\xc1h\x98\xe5\xf7\x0e\xaax\x1c\x90\x117\xca0\xe4\x1a\xdc\xb1`\xd4\x03z\x86m\xc2\xcc5\x8aWZR(:\x99.\x95\x94\n\xd2=\xb7jWFsT\x12\x8c\r-\xe6\xf3?5\xc0\xf2`\xdee\xb7\xec<\x91Px\x0eoi\x0bS\xf0\xcb?\xd9-\xbb\xb8\t\xa5W\x933
xdc+\xe6\x9a\xdf\xb7\xf0\xc5\xfd:\\\xdc\xc0\xc3w\xfe>\xf3_PK\x03\x04\x14\x00\x00\x00\x08\x00\xbd\xaa\xdbJYH\xff\xbb\xfa\x00\x00\x008\x03\x00\x00\x08\x00\x00\x00meta.xml\x8d\x92\xc1N\x840\x14E\xf7~\x05a\xc3\n\x10\x8d\x89iJgcf\xab\x0b]\xb8\xac\xe5ulB\xdf#mG\xf1\xef-\x08Ig\xe2\xa2;R\xce\xb9mn.?\xccv,\xbe\xc0yC\xd8W]s[\x15\x80\x8a\x06\x83\xa7\xbez{=\xd6\x8f\xd5A\xdcp\xd2\xda(`\x03\xa9\xb3\x05\x0c\xb5\x85 \x8b\xa8\xa2gA~\x8c\xd0\x97g\x87\x8c\xa47\x9e\xa1\xb4\x10\x8f\x15\xa3\tp7X\x02\xb3xM\xb9\xd9\x9ar\xd5\xd9\x8f\xb5\xa6Z\x91\x9dd0W1V\xa2\xd1\xe0Cn\xd8\xce\xa7\x19\x93\x03\x1f\x89\x18\x1e\xab\xc8\xccI\x9d\x8b\xf7\xc4~\xb2\xdf\x12\xd9\xd4\xf5\xe1\'\xbf\xd0\x15Nm\xf5)]v\r+\x9c\xda\x83\x93\xdf\xb9\xf2\xc2\xc6\x99\xa4z\x809\xfb\xee\x85M\xdd\xbf\x89\xe5\xda\xdb W\x7f\xfb\xdeW\\v\xcd])\xf6\xc9.\xed\n\xbev|\x02\x04\'\x039\xf1\xfct|yo\xbb\xe6\xbey\xe0\xed\xd5?\xde^\x98\xed\x7f\xd3\x17\xbfPK\x03\x04\x14\x00\x00\x00\x08\x00\xbd\xaa\xdbJ\xe4|\xf7\xd3 \x01\x00\x00F\x04\x00\x00\x15\x00\x00\x00META-INF/manifest.xml\xad\x94\xcdn\x84 \x14\x85\xf7}\n\xe3\xc6\x15\xda\xee\x1a2:\xbby\x82\xf6\x01(^*\t\x02\x01\x9c\xea\xdb\xf7Bk\xa5?\x0b\x9a\xcc\xce\xe89\xdf\xfd;\xf1t^gU]\xc1yit\xdf<\xb4\xf7M\x05\x9a\x9bQ\xea\xd7\xbey~\xba\x90\xc7\xe6<\xdc\x9df\xa6\xa5\x00\x1f\xe8\xfeP\xa1O{\x1a\xd8\x8b\x82\xbe^\x9c\xa6\x86y\xe9\xa9f3\xe0kN\x8d\x05=\x1a\xbe\xcc\xa0\x03\xcd\xc4\x14k\xd4\x9fnaJ\xad\xabWD\x18\xc2\xcdlY\x90?0{O\xa5\xb0\xafa2\x86u\xe0Q\x81p\xdcC!\'\xf7|\xeb\x07\x02+\xee\x05\xb5\xb9\xd7\x87\xad|\xa1I\x9c\xbb\xf9\xc4\\\xf1\x1a\x928w\x8f\x8e\xbd\x95\x9a\xa3\x163\x92\xdb\x03\xac\xc5\x ...

# %% [markdown]
# Now that you know what to do, save the file:

# %%
# YOUR CODE GOES HERE

# %% [markdown]
# Time for an exercise. Use your knowledge of web APIs to pull in some JSON-formatted data from an API, save it to a JSON file, and then use `tablib` to convert it to a CSV file. Then use `odo` to consume the CSV file and convert it to a pandas DataFrame.
